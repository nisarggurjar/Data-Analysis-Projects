# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(0,6,1)
y = np.arange(0,11,2)
x2 = np.arange(0,4.5,.5)
plt.figure(figsize=(5,3),dpi=100)
plt.title('2X', fontdict={'fontsize':20, 'fontname': 'Comic Sans MS'})
plt.xlabel('X Axis')
plt.ylabel('y Axis', )
#fmt = [color][marker][line]
plt.plot(x,y,'y^--', label='2X')
plt.plot(x2[:5], x2[:5]**2,'r', label='x^2')
plt.plot(x2[4:], x2[4:]**2,'r--')
#plt.plot(x,y, label='2X', color='#abcdef', linewidth=4, marker='*', markersize=10,markeredgecolor='red', linestyle='--')
plt.legend()
plt.show()
plt.savefig('grap.png', dpi=300)

# %%
labels = ['A','B','C']
values = [2,4,6]
bars = plt.bar(labels, values)
patterns = ['/', '*', 'o']
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.show()

# %%
gas = pd.read_csv('Gas_prices.csv')
plt.figure(figsize=(10,5))
for country in gas:
    if country!='Year':
        plt.plot(gas.Year, gas[country],marker = '.')
plt.legend()
plt.xticks(gas.Year[::3].tolist()+[2011])
# Out:
# ([<matplotlib.axis.XTick at 0x2939f83cef0>,
# ...
#  <a list of 8 Text xticklabel objects>)

# %%
fifa = pd.read_csv('fifa_data.csv')

# %%
bins = [40,50,60,70,80,90,100]
plt.hist(fifa.Overall, bins=bins, color='#ababab')
# Out:
# (array([  89., 2815., 9665., 5083.,  541.,   14.]),
#  array([ 40,  50,  60,  70,  80,  90, 100]),
#  <a list of 6 Patch objects>)

# %%
left = fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]
colors = ['g','y']
labels = ['Left', 'Right']
val =[left,right]
plt.pie(val,colors = colors, labels = labels, autopct='%.2f %%')
plt.title('FIFA')
plt.show()

# %%
label=['A','B','C']
values=[1,2,4]
bars=plt.bar(label,values)
pattern=['/','*','\\']
for bar in bars:
    bar.set_hatch(pattern.pop(0))
plt.show()

# %%
fifa.Weight = [ int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight ]
type(fifa.Weight[0])
# Out:
# numpy.float64

# %%
light = fifa.loc[fifa.Weight<125].count()[0]
light_medium = fifa.loc[(fifa.Weight>=125) & (fifa.Weight<150)].count()[0]
medium = fifa.loc[(fifa.Weight>=150) & (fifa.Weight<175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight>=175) & (fifa.Weight<200)].count()[0]
heavy = fifa.loc[fifa.Weight>=200].count()[0]

# %%
weights = [light,light_medium,medium,medium_heavy,heavy]
labels = ['Under 125', '125-150','150-175','175-200','above 200']
plt.style.use('ggplot')
explode = [.4,.2,0,0,.4]
plt.pie(weights,labels=labels,explode = explode, autopct='%.2f %%', pctdistance = .8)
plt.show()

# %%
barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']
revs = fifa.loc[fifa.Club == 'New England Revolution']['Overall']
plt.style.use('default')
labels = ['Barcelona', 'Real Madrid', 'New England Revolution']
boxes = plt.boxplot([barcelona,madrid,revs],labels=labels,patch_artist=True, medianprops={'linewidth':2})
for box in boxes['boxes']:
    box.set(color ='r',linewidth=2)
    box.set(facecolor='g')
plt.show()
